# %%
# !pip install pandas numpy

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("/content/credit_card_approval_dataset.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Candidate Name  1000 non-null   object
#  1   Age             1000 non-null   int64
#  2   Gender          1000 non-null   object
#  3   Salary          1000 non-null   int64
#  4   Income          1000 non-null   int64
#  5   Job Details     1000 non-null   object
#  6   Credit History  1000 non-null   object
#  7   Credit Score    1000 non-null   int64
#  8   Existing Loans  1000 non-null   int64
#  9   Credit Status   1000 non-null   object
# dtypes: int64(5), object(5)
# memory usage: 78.3+ KB

# %%
df.isnull().sum()
# Out:
# Candidate Name    0
# Age               0
# Gender            0
# Salary            0
# Income            0
# Job Details       0
# Credit History    0
# Credit Score      0
# Existing Loans    0
# Credit Status     0
# dtype: int64

# %%
df.drop_duplicates(inplace=True)

# %%
df.fillna("Unknown",inplace=True)

# %%
df.columns=df.columns.str.strip()

# %%
df.to_csv("cleaned_dataset.csv",index=False)

# %%
salary = np.array(df["Salary"])
credit_score = np.array(df["Credit Score"])
salary
# Out:
# array([72978, 85895, 58514, 94444, 20894, 24904, 78786, 91788, 39546,
#        39419, 54563, 50459, 76147, 54088, 49181, 63188, 90542, 28577,
#        50087, 66546, 71481, 46099, 58931, 65605, 42441, 49762, 84845,
#        81089, 66136, 78006, 88298, 63738, 65005, 62771, 69946, 89042,
#        35482, 41547, 29405, 31188, 75164, 50165, 34000, 75000, 69609,
#        98577, 53506, 95886, 50211, 66896, 48877, 39617, 40791, 72688,
#        37850, 59785, 37035, 66605, 43086, 77081, 52342, 53988, 25564,
#        35285, 25973, 59613, 92653, 30910, 37058, 47304, 68057, 96063,
#        68752, 49457, 57603, 41562, 54042, 73328, 51040, 51497, 31396,
#        27502, 80766, 29976, 21689, 48695, 91347, 98711, 56459, 46969,
#        47609, 68047, 54899, 34589, 80544, 47668, 31533, 93966, 83341,
#        89504, 76498, 59526, 47886, 54716, 40146, 53997, 66627, 74867,
#        65542, 59117, 51207, 38307, 32054, 24824, 72114, 60228, 82781,
# ...

# %%
np.mean(df['Salary'])
# Out:
# np.float64(60566.878)

# %%
np.median(df['Salary'])
# Out:
# np.float64(59832.5)

# %%
np.std(df['Salary'])
# Out:
# 22354.38398039892

# %%
np.var(df['Credit Score'])
# Out:
# 29299.38543600003

# %%
m=np.min(salary)
n=np.max(salary)
m,n
# Out:
# (np.int64(20029), np.int64(99958))

# %%
np.sum(salary)
# Out:
# np.int64(60566878)

# %%
high_salary = salary[salary > 50000]
high_salary
# Out:
# array([72978, 85895, 58514, 94444, 78786, 91788, 54563, 50459, 76147,
#        54088, 63188, 90542, 50087, 66546, 71481, 58931, 65605, 84845,
#        81089, 66136, 78006, 88298, 63738, 65005, 62771, 69946, 89042,
#        75164, 50165, 75000, 69609, 98577, 53506, 95886, 50211, 66896,
#        72688, 59785, 66605, 77081, 52342, 53988, 59613, 92653, 68057,
#        96063, 68752, 57603, 54042, 73328, 51040, 51497, 80766, 91347,
#        98711, 56459, 68047, 54899, 80544, 93966, 83341, 89504, 76498,
#        59526, 54716, 53997, 66627, 74867, 65542, 59117, 51207, 72114,
#        60228, 82781, 78238, 88057, 61547, 50229, 81254, 95182, 78538,
#        51085, 97613, 65967, 62559, 91723, 50927, 80442, 90948, 72423,
#        92408, 62045, 80794, 81832, 68917, 77677, 77592, 77527, 68340,
#        75287, 84062, 90805, 75537, 79771, 96231, 58792, 82876, 96291,
#        56591, 99211, 81608, 69184, 92559, 68205, 67927, 70194, 66098,
# ...

# %%
df.groupby("Credit Status")["Salary"].mean()
# Out:
# Credit Status
# Approved    69977.958333
# Rejected    59567.471239
# Name: Salary, dtype: float64

# %%
df["Credit Status"].value_counts()
# Out:
# Credit Status
# Rejected    904
# Approved     96
# Name: count, dtype: int64

# %%
np.mean(df['Credit Status'] == 'Approved')
# Out:
# np.float64(0.096)
